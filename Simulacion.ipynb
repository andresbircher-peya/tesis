# %%
import simpy
import random

def cliente(env, nombre, cajas):
    """Simula la llegada de un cliente a una cola en el supermercado"""
    print(f"{nombre} llega al supermercado en el minuto {env.now:.2f}")
    with cajas.request() as turno:
        yield turno  # Esperar turno en la caja
        print(f"{nombre} comienza a ser atendido en el minuto {env.now:.2f}")
        yield env.timeout(random.uniform(2, 5))  # Tiempo de atención
        print(f"{nombre} termina en el minuto {env.now:.2f}")

def llegada_clientes(env, cajas):
    """Genera clientes de manera aleatoria"""
    cliente_id = 0
    while True:
        yield env.timeout(random.uniform(1, 3))  # Tiempo entre llegadas
        cliente_id += 1
        env.process(cliente(env, f"Cliente {cliente_id}", cajas))

# Configuración de la simulación
env = simpy.Environment()
cajas = simpy.Resource(env, capacity=3)  # 3 cajas registradoras
env.process(llegada_clientes(env, cajas))

# Ejecutar la simulación por 20 minutos
env.run(until=200)
# Out:
# Cliente 1 llega al supermercado en el minuto 2.12
# Cliente 1 comienza a ser atendido en el minuto 2.12
# Cliente 2 llega al supermercado en el minuto 3.23
# Cliente 2 comienza a ser atendido en el minuto 3.23
# Cliente 3 llega al supermercado en el minuto 5.38
# Cliente 3 comienza a ser atendido en el minuto 5.38
# Cliente 2 termina en el minuto 6.33
# Cliente 1 termina en el minuto 6.82
# Cliente 4 llega al supermercado en el minuto 8.20
# Cliente 4 comienza a ser atendido en el minuto 8.20
# Cliente 5 llega al supermercado en el minuto 9.52
# Cliente 5 comienza a ser atendido en el minuto 9.52
# Cliente 3 termina en el minuto 9.99
# Cliente 6 llega al supermercado en el minuto 11.77
# Cliente 6 comienza a ser atendido en el minuto 11.77
# Cliente 5 termina en el minuto 12.39
# Cliente 4 termina en el minuto 12.78
# Cliente 7 llega al supermercado en el minuto 14.02
# Cliente 7 comienza a ser atendido en el minuto 14.02
# Cliente 8 llega al supermercado en el minuto 15.38
# Cliente 8 comienza a ser atendido en el minuto 15.38
# Cliente 6 termina en el minuto 16.23
# Cliente 7 termina en el minuto 16.75
# Cliente 9 llega al supermercado en el minuto 17.01
# Cliente 9 comienza a ser atendido en el minuto 17.01
# Cliente 8 termina en el minuto 17.58
# Cliente 9 termina en el minuto 19.91
# Cliente 10 llega al supermercado en el minuto 19.99
# Cliente 10 comienza a ser atendido en el minuto 19.99
# Cliente 11 llega al supermercado en el minuto 22.01
# Cliente 11 comienza a ser atendido en el minuto 22.01
# Cliente 12 llega al supermercado en el minuto 23.06
# Cliente 12 comienza a ser atendido en el minuto 23.06
# Cliente 10 termina en el minuto 23.27
# Cliente 13 llega al supermercado en el minuto 24.29
# Cliente 13 comienza a ser atendido en el minuto 24.29
# Cliente 11 termina en el minuto 25.97
# Cliente 14 llega al supermercado en el minuto 27.29
# Cliente 14 comienza a ser atendido en el minuto 27.29
# Cliente 12 termina en el minuto 27.42
# Cliente 13 termina en el minuto 29.06
# Cliente 15 llega al supermercado en el minuto 29.47
# Cliente 15 comienza a ser atendido en el minuto 29.47
# Cliente 16 llega al supermercado en el minuto 30.75
# Cliente 16 comienza a ser atendido en el minuto 30.75
# Cliente 14 termina en el minuto 31.20
# Cliente 17 llega al supermercado en el minuto 33.00
# Cliente 17 comienza a ser atendido en el minuto 33.00
# Cliente 16 termina en el minuto 33.03
# Cliente 15 termina en el minuto 33.73
# Cliente 18 llega al supermercado en el minuto 34.62
# Cliente 18 comienza a ser atendido en el minuto 34.62
# Cliente 17 termina en el minuto 36.19
# Cliente 19 llega al supermercado en el minuto 36.22
# Cliente 19 comienza a ser atendido en el minuto 36.22
# Cliente 20 llega al supermercado en el minuto 37.64
# Cliente 20 comienza a ser atendido en el minuto 37.64
# Cliente 21 llega al supermercado en el minuto 39.23
# Cliente 18 termina en el minuto 39.37
# Cliente 21 comienza a ser atendido en el minuto 39.37
# Cliente 19 termina en el minuto 39.42
# Cliente 20 termina en el minuto 39.98
# Cliente 22 llega al supermercado en el minuto 40.88
# Cliente 22 comienza a ser atendido en el minuto 40.88
# Cliente 21 termina en el minuto 41.66
# Cliente 23 llega al supermercado en el minuto 43.51
# Cliente 23 comienza a ser atendido en el minuto 43.51
# Cliente 22 termina en el minuto 45.04
# Cliente 24 llega al supermercado en el minuto 45.31
# Cliente 24 comienza a ser atendido en el minuto 45.31
# Cliente 23 termina en el minuto 45.58
# Cliente 25 llega al supermercado en el minuto 47.26
# Cliente 25 comienza a ser atendido en el minuto 47.26
# Cliente 26 llega al supermercado en el minuto 50.08
# Cliente 26 comienza a ser atendido en el minuto 50.08
# Cliente 24 termina en el minuto 50.20
# Cliente 25 termina en el minuto 52.01
# Cliente 27 llega al supermercado en el minuto 52.04
# Cliente 27 comienza a ser atendido en el minuto 52.04
# Cliente 26 termina en el minuto 52.11
# Cliente 28 llega al supermercado en el minuto 54.55
# Cliente 28 comienza a ser atendido en el minuto 54.55
# Cliente 27 termina en el minuto 56.22
# Cliente 29 llega al supermercado en el minuto 56.25
# Cliente 29 comienza a ser atendido en el minuto 56.25
# Cliente 28 termina en el minuto 57.42
# Cliente 30 llega al supermercado en el minuto 58.19
# Cliente 30 comienza a ser atendido en el minuto 58.19
# Cliente 29 termina en el minuto 58.34
# Cliente 31 llega al supermercado en el minuto 61.04
# Cliente 31 comienza a ser atendido en el minuto 61.04
# Cliente 30 termina en el minuto 62.69
# Cliente 32 llega al supermercado en el minuto 63.01
# Cliente 32 comienza a ser atendido en el minuto 63.01
# Cliente 33 llega al supermercado en el minuto 65.03
# Cliente 33 comienza a ser atendido en el minuto 65.03
# Cliente 31 termina en el minuto 65.04
# Cliente 34 llega al supermercado en el minuto 66.50
# Cliente 34 comienza a ser atendido en el minuto 66.50
# Cliente 32 termina en el minuto 66.60
# Cliente 35 llega al supermercado en el minuto 68.56
# Cliente 35 comienza a ser atendido en el minuto 68.56
# Cliente 33 termina en el minuto 69.65
# Cliente 36 llega al supermercado en el minuto 70.30
# Cliente 36 comienza a ser atendido en el minuto 70.30
# Cliente 34 termina en el minuto 70.68
# Cliente 37 llega al supermercado en el minuto 72.48
# Cliente 37 comienza a ser atendido en el minuto 72.48
# Cliente 35 termina en el minuto 73.20
# Cliente 36 termina en el minuto 73.56
# Cliente 38 llega al supermercado en el minuto 74.47
# Cliente 38 comienza a ser atendido en el minuto 74.47
# Cliente 39 llega al supermercado en el minuto 76.25
# Cliente 39 comienza a ser atendido en el minuto 76.25
# Cliente 37 termina en el minuto 76.47
# Cliente 38 termina en el minuto 76.55
# Cliente 40 llega al supermercado en el minuto 77.63
# Cliente 40 comienza a ser atendido en el minuto 77.63
# Cliente 39 termina en el minuto 78.28
# Cliente 41 llega al supermercado en el minuto 78.97
# Cliente 41 comienza a ser atendido en el minuto 78.97
# Cliente 42 llega al supermercado en el minuto 80.24
# Cliente 42 comienza a ser atendido en el minuto 80.24
# Cliente 40 termina en el minuto 81.59
# Cliente 43 llega al supermercado en el minuto 81.82
# Cliente 43 comienza a ser atendido en el minuto 81.82
# Cliente 41 termina en el minuto 82.01
# Cliente 44 llega al supermercado en el minuto 83.09
# Cliente 44 comienza a ser atendido en el minuto 83.09
# Cliente 45 llega al supermercado en el minuto 84.14
# Cliente 42 termina en el minuto 85.05
# Cliente 45 comienza a ser atendido en el minuto 85.05
# Cliente 46 llega al supermercado en el minuto 85.50
# Cliente 43 termina en el minuto 85.68
# Cliente 46 comienza a ser atendido en el minuto 85.68
# Cliente 47 llega al supermercado en el minuto 86.57
# Cliente 44 termina en el minuto 87.50
# Cliente 47 comienza a ser atendido en el minuto 87.50
# Cliente 48 llega al supermercado en el minuto 87.66
# Cliente 45 termina en el minuto 88.27
# Cliente 48 comienza a ser atendido en el minuto 88.27
# Cliente 49 llega al supermercado en el minuto 88.98
# Cliente 46 termina en el minuto 90.05
# Cliente 49 comienza a ser atendido en el minuto 90.05
# Cliente 47 termina en el minuto 90.17
# Cliente 50 llega al supermercado en el minuto 90.76
# Cliente 50 comienza a ser atendido en el minuto 90.76
# Cliente 48 termina en el minuto 91.77
# Cliente 51 llega al supermercado en el minuto 93.02
# Cliente 51 comienza a ser atendido en el minuto 93.02
# Cliente 49 termina en el minuto 94.95
# Cliente 50 termina en el minuto 95.25
# Cliente 52 llega al supermercado en el minuto 95.54
# Cliente 52 comienza a ser atendido en el minuto 95.54
# Cliente 53 llega al supermercado en el minuto 97.26
# Cliente 53 comienza a ser atendido en el minuto 97.26
# Cliente 51 termina en el minuto 97.84
# Cliente 52 termina en el minuto 97.97
# Cliente 54 llega al supermercado en el minuto 99.80
# Cliente 54 comienza a ser atendido en el minuto 99.80
# Cliente 53 termina en el minuto 100.37
# Cliente 55 llega al supermercado en el minuto 101.18
# Cliente 55 comienza a ser atendido en el minuto 101.18
# Cliente 56 llega al supermercado en el minuto 103.98
# Cliente 56 comienza a ser atendido en el minuto 103.98
# Cliente 54 termina en el minuto 104.21
# Cliente 55 termina en el minuto 105.47
# Cliente 57 llega al supermercado en el minuto 105.77
# Cliente 57 comienza a ser atendido en el minuto 105.77
# Cliente 58 llega al supermercado en el minuto 107.37
# Cliente 58 comienza a ser atendido en el minuto 107.37
# Cliente 56 termina en el minuto 108.43
# Cliente 57 termina en el minuto 108.51
# Cliente 59 llega al supermercado en el minuto 108.90
# Cliente 59 comienza a ser atendido en el minuto 108.90
# Cliente 58 termina en el minuto 111.46
# Cliente 60 llega al supermercado en el minuto 111.62
# Cliente 60 comienza a ser atendido en el minuto 111.62
# Cliente 59 termina en el minuto 112.48
# Cliente 61 llega al supermercado en el minuto 114.17
# Cliente 61 comienza a ser atendido en el minuto 114.17
# Cliente 60 termina en el minuto 114.73
# Cliente 62 llega al supermercado en el minuto 116.13
# Cliente 62 comienza a ser atendido en el minuto 116.13
# Cliente 61 termina en el minuto 117.40
# Cliente 63 llega al supermercado en el minuto 119.09
# Cliente 63 comienza a ser atendido en el minuto 119.09
# Cliente 62 termina en el minuto 120.16
# Cliente 64 llega al supermercado en el minuto 120.44
# Cliente 64 comienza a ser atendido en el minuto 120.44
# Cliente 63 termina en el minuto 121.40
# Cliente 65 llega al supermercado en el minuto 121.91
# Cliente 65 comienza a ser atendido en el minuto 121.91
# Cliente 66 llega al supermercado en el minuto 123.65
# Cliente 66 comienza a ser atendido en el minuto 123.65
# Cliente 64 termina en el minuto 125.22
# Cliente 67 llega al supermercado en el minuto 125.35
# Cliente 67 comienza a ser atendido en el minuto 125.35
# Cliente 65 termina en el minuto 126.67
# Cliente 68 llega al supermercado en el minuto 126.72
# Cliente 68 comienza a ser atendido en el minuto 126.72
# Cliente 66 termina en el minuto 127.71
# Cliente 67 termina en el minuto 128.15
# Cliente 69 llega al supermercado en el minuto 128.94
# Cliente 69 comienza a ser atendido en el minuto 128.94
# Cliente 68 termina en el minuto 129.20
# Cliente 70 llega al supermercado en el minuto 131.04
# Cliente 70 comienza a ser atendido en el minuto 131.04
# Cliente 69 termina en el minuto 132.29
# Cliente 71 llega al supermercado en el minuto 132.67
# Cliente 71 comienza a ser atendido en el minuto 132.67
# Cliente 70 termina en el minuto 134.15
# Cliente 72 llega al supermercado en el minuto 135.27
# Cliente 72 comienza a ser atendido en el minuto 135.27
# Cliente 71 termina en el minuto 135.69
# Cliente 73 llega al supermercado en el minuto 137.07
# Cliente 73 comienza a ser atendido en el minuto 137.07
# Cliente 72 termina en el minuto 138.74
# Cliente 74 llega al supermercado en el minuto 139.54
# Cliente 74 comienza a ser atendido en el minuto 139.54
# Cliente 73 termina en el minuto 141.22
# Cliente 75 llega al supermercado en el minuto 141.66
# Cliente 75 comienza a ser atendido en el minuto 141.66
# Cliente 76 llega al supermercado en el minuto 143.51
# Cliente 76 comienza a ser atendido en el minuto 143.51
# Cliente 74 termina en el minuto 143.88
# Cliente 77 llega al supermercado en el minuto 145.12
# Cliente 77 comienza a ser atendido en el minuto 145.12
# Cliente 75 termina en el minuto 145.90
# Cliente 78 llega al supermercado en el minuto 146.75
# Cliente 78 comienza a ser atendido en el minuto 146.75
# Cliente 76 termina en el minuto 147.65
# Cliente 77 termina en el minuto 147.93
# Cliente 79 llega al supermercado en el minuto 148.83
# Cliente 79 comienza a ser atendido en el minuto 148.83
# Cliente 78 termina en el minuto 149.21
# Cliente 80 llega al supermercado en el minuto 150.52
# Cliente 80 comienza a ser atendido en el minuto 150.52
# Cliente 79 termina en el minuto 152.32
# Cliente 81 llega al supermercado en el minuto 152.95
# Cliente 81 comienza a ser atendido en el minuto 152.95
# Cliente 82 llega al supermercado en el minuto 154.64
# Cliente 82 comienza a ser atendido en el minuto 154.64
# Cliente 80 termina en el minuto 154.75
# Cliente 81 termina en el minuto 155.66
# Cliente 83 llega al supermercado en el minuto 156.81
# Cliente 83 comienza a ser atendido en el minuto 156.81
# Cliente 82 termina en el minuto 157.96
# Cliente 84 llega al supermercado en el minuto 158.19
# Cliente 84 comienza a ser atendido en el minuto 158.19
# Cliente 85 llega al supermercado en el minuto 159.92
# Cliente 85 comienza a ser atendido en el minuto 159.92
# Cliente 86 llega al supermercado en el minuto 160.96
# Cliente 84 termina en el minuto 161.14
# Cliente 86 comienza a ser atendido en el minuto 161.14
# Cliente 83 termina en el minuto 161.61
# Cliente 87 llega al supermercado en el minuto 162.31
# Cliente 87 comienza a ser atendido en el minuto 162.31
# Cliente 88 llega al supermercado en el minuto 163.45
# Cliente 85 termina en el minuto 163.83
# Cliente 88 comienza a ser atendido en el minuto 163.83
# Cliente 86 termina en el minuto 165.59
# Cliente 89 llega al supermercado en el minuto 165.67
# Cliente 89 comienza a ser atendido en el minuto 165.67
# Cliente 87 termina en el minuto 167.16
# Cliente 90 llega al supermercado en el minuto 167.84
# Cliente 90 comienza a ser atendido en el minuto 167.84
# Cliente 88 termina en el minuto 168.18
# Cliente 89 termina en el minuto 168.68
# Cliente 91 llega al supermercado en el minuto 169.12
# Cliente 91 comienza a ser atendido en el minuto 169.12
# Cliente 92 llega al supermercado en el minuto 171.46
# Cliente 92 comienza a ser atendido en el minuto 171.46
# Cliente 90 termina en el minuto 171.89
# Cliente 93 llega al supermercado en el minuto 173.33
# Cliente 93 comienza a ser atendido en el minuto 173.33
# Cliente 91 termina en el minuto 173.86
# Cliente 92 termina en el minuto 175.06
# Cliente 94 llega al supermercado en el minuto 175.24
# Cliente 94 comienza a ser atendido en el minuto 175.24
# Cliente 93 termina en el minuto 177.47
# Cliente 95 llega al supermercado en el minuto 177.69
# Cliente 95 comienza a ser atendido en el minuto 177.69
# Cliente 94 termina en el minuto 178.03
# Cliente 96 llega al supermercado en el minuto 179.78
# Cliente 96 comienza a ser atendido en el minuto 179.78
# Cliente 95 termina en el minuto 181.45
# Cliente 97 llega al supermercado en el minuto 182.51
# Cliente 97 comienza a ser atendido en el minuto 182.51
# Cliente 96 termina en el minuto 182.71
# Cliente 98 llega al supermercado en el minuto 185.37
# Cliente 98 comienza a ser atendido en el minuto 185.37
# Cliente 97 termina en el minuto 186.16
# Cliente 99 llega al supermercado en el minuto 187.61
# Cliente 99 comienza a ser atendido en el minuto 187.61
# Cliente 100 llega al supermercado en el minuto 188.90
# Cliente 100 comienza a ser atendido en el minuto 188.90
# Cliente 98 termina en el minuto 189.22
# Cliente 99 termina en el minuto 190.07
# Cliente 101 llega al supermercado en el minuto 191.28
# Cliente 101 comienza a ser atendido en el minuto 191.28
# Cliente 100 termina en el minuto 192.38
# Cliente 102 llega al supermercado en el minuto 193.56
# Cliente 102 comienza a ser atendido en el minuto 193.56
# Cliente 101 termina en el minuto 194.15
# Cliente 103 llega al supermercado en el minuto 194.99
# Cliente 103 comienza a ser atendido en el minuto 194.99
# Cliente 102 termina en el minuto 196.47
# Cliente 104 llega al supermercado en el minuto 196.73
# Cliente 104 comienza a ser atendido en el minuto 196.73
# Cliente 103 termina en el minuto 197.03
# Cliente 105 llega al supermercado en el minuto 199.06
# Cliente 105 comienza a ser atendido en el minuto 199.06
# Cliente 104 termina en el minuto 199.37
